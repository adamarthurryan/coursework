# %%
from astropy.time import Time
import astropy.units as u

obs_start_s='2026-03-31T06:46:08.130'
obs_start_f=61130.2820289 * u.d
obs_length = 18.118 * u.s
#obs = Time(obs_f, format="mjd", scale="utc").tdb
obs_start = Time(obs_start_f, format="mjd", scale="utc")
obs_end = obs_start + obs_length
#display(obs)
#obs = obs.tdb
display(obs_end.jd)
display(obs_end.tdb.jd)
display(obs_end.tt.jd)

mid_transit_s = "2026-03-31 06:53"#from exoplanetwatch
#mid_transit_f = 2461128.11774203 #from exotic
mid_transit = Time(mid_transit_s, format="iso", scale='tdb')
display(mid_transit)

period_days = 2.676*u.day
#next_mid_transit = mid_transit+period_days
#display(next_mid_transit.utc.isot)


dt = obs_end-mid_transit
dt.to(u.s)
# Out:
# np.float64(2461130.782238599)
# np.float64(2461130.7830393584)
# np.float64(2461130.78303934)
# <Time object: scale='tdb' format='iso' value=2026-03-31 06:53:00.000>
# <Quantity -325.39941098 s>

# %%
(0.00055243*u.d).to(u.s)
# Out:
# <Quantity 47.729952 s>
